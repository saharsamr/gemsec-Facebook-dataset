# %%
import networkit as nk
import graph_tool.all as gt
import networkx as nx

import powerlaw
import matplotlib.pyplot as plt

from plots import Plots
from tools import values_frequency
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# ## load

# %%
snapReader = nk.graphio.SNAPGraphReader(False, False)
G_nk = snapReader.read("data/facebook_clean_data/new_sites_edges.csv")

# %%
G_gt = gt.load_graph_from_csv("data/facebook_clean_data/new_sites_edges.csv", csv_options={"delimiter": " "})

# %% [markdown]
# ## topology parameters

# %%
degrees = [G_nk.degree(v) for v in G_nk.iterNodes()]
degree_distr = sorted(nk.centrality.DegreeCentrality(G_nk).run().scores(), reverse=True)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_nk.numberOfNodes()))
print('number of edges: {}'.format(G_nk.numberOfEdges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 27917
# number of edges: 206259
# min degree: 1
# max degree: 678
# average degree: 14.766020704230398
# ----------------------------------------------------------------
# estimated gamma: 3.432841403240434
# Calculating best minimal value for power law fit
# /home/sahar/Documents/NetworkAnalysis/venv/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /

# %%
degrees = G_gt.get_total_degrees(G_gt.get_vertices())
degree_distr, freq = values_frequency(degrees)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_gt.num_vertices()))
print('number of edges: {}'.format(G_gt.num_edges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 27917
# number of edges: 206259
# min degree: 1
# max degree: 678
# average degree: 14.776587742235913
# ----------------------------------------------------------------
# estimated gamma: 2.734349580681313
# Calculating best minimal value for power law fit

# %% [markdown]
# ## graph density

# %%
# %time
graph_density = G_nk.numberOfEdges() / ((G_nk.numberOfNodes()*(G_nk.numberOfNodes()-1))/2)
print('the graph density equals: {}'.format(graph_density))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.48 µs
# the graph density equals: 0.000529323246247167

# %% [markdown]
# ## clustering coefficient

# %%
# %time
clustering_coefficient = nk.globals.clustering(G_nk)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient))
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 14.8 µs
# the clustering coefficient of the graph equals: 0.3213758360114653

# %%
# %time
clustering_coefficient = gt.global_clustering(G_gt)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient[0]))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# the clustering coefficient of the graph equals: 0.11398478178835561

# %% [markdown]
# ## assortativity

# %%
# %time
G_nx = nk.nxadapter.nk2nx(G_nk)
assortativity = nx.degree_assortativity_coefficient(G_nx)
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# assortativity coefficient is: 0.021954006196974844

# %%
# %time
assortativity = gt.assortativity(G_gt, "total")
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.29 µs
# assortativity coefficient is: (0.009376809716601328, 0.0003282454882932988)

# %% [markdown]
# # community detection

# %% [markdown]
# ## label propagation

# %%
# %timeit label_prop_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.16346335411071777 [s]
# solution properties:
# -------------------  ----------
# # communities          52
# min community size      4
# max community size   4080
# avg. community size   536.865
# modularity              0.62552
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.13046622276306152 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3980
# avg. community size   606.891
# modularity              0.622907
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07355451583862305 [s]
# solution properties:
# -------------------  -----------
# # communities          54
# min community size      3
# max community size   4145
# avg. community size   516.981
# modularity              0.623395
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08147048950195312 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4066
# avg. community size   593.979
# modularity              0.624661
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.13705182075500488 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4109
# avg. community size   606.891
# modularity              0.625091
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07925939559936523 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   4082
# avg. community size   697.925
# modularity              0.624462
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06495165824890137 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   3697
# avg. community size   620.378
# modularity              0.623679
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.12158942222595215 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      4
# max community size   4083
# avg. community size   715.821
# modularity              0.625271
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06245994567871094 [s]
# solution properties:
# -------------------  ----------
# # communities          50
# min community size      4
# max community size   4067
# avg. community size   558.34
# modularity              0.62706
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.08670544624328613 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4049
# avg. community size   606.891
# modularity              0.625487
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09969329833984375 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   3661
# avg. community size   581.604
# modularity              0.625648
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09135913848876953 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4023
# avg. community size   593.979
# modularity              0.625352
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.11523962020874023 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   4035
# avg. community size   569.735
# modularity              0.626991
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.24268579483032227 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      3
# max community size   3825
# avg. community size   680.902
# modularity              0.625245
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.058852195739746094 [s]
# solution properties:
# -------------------  -----------
# # communities          52
# min community size      4
# max community size   4106
# avg. community size   536.865
# modularity              0.625072
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09271836280822754 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4014
# avg. community size   593.979
# modularity              0.625033
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.1903831958770752 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      3
# max community size   4196
# avg. community size   606.891
# modularity              0.622314
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.12613677978515625 [s]
# solution properties:
# -------------------  -----------
# # communities          50
# min community size      4
# max community size   3850
# avg. community size   558.34
# modularity              0.624812
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.10971951484680176 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   4039
# avg. community size   664.69
# modularity              0.622907
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.2669258117675781 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   3996
# avg. community size   620.378
# modularity              0.624473
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09448909759521484 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   3944
# avg. community size   634.477
# modularity              0.624646
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.2145078182220459 [s]
# solution properties:
# -------------------  -----------
# # communities          52
# min community size      4
# max community size   4101
# avg. community size   536.865
# modularity              0.625093
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06271076202392578 [s]
# solution properties:
# -------------------  ----------
# # communities          40
# min community size      4
# max community size   4091
# avg. community size   697.925
# modularity              0.62526
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.09126114845275879 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   3996
# avg. community size   593.979
# modularity              0.625177
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06844091415405273 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   4084
# avg. community size   680.902
# modularity              0.624788
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06356620788574219 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   4031
# avg. community size   569.735
# modularity              0.623535
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07494950294494629 [s]
# solution properties:
# -------------------  -----------
# # communities          50
# min community size      4
# max community size   3859
# avg. community size   558.34
# modularity              0.625287
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0683889389038086 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4110
# avg. community size   593.979
# modularity              0.623127
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07046747207641602 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4027
# avg. community size   606.891
# modularity              0.624544
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.058458566665649414 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4058
# avg. community size   547.392
# modularity              0.623186
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08611798286437988 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4067
# avg. community size   547.392
# modularity              0.624948
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.1451730728149414 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   3984
# avg. community size   569.735
# modularity              0.625745
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08039426803588867 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4027
# avg. community size   620.378
# modularity              0.624546
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07417821884155273 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   3618
# avg. community size   593.979
# modularity              0.624211
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.12886500358581543 [s]
# solution properties:
# -------------------  ----------
# # communities          49
# min community size      4
# max community size   3978
# avg. community size   569.735
# modularity              0.62609
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.07332468032836914 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4106
# avg. community size   606.891
# modularity              0.624452
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07421183586120605 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3970
# avg. community size   606.891
# modularity              0.626164
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05850529670715332 [s]
# solution properties:
# -------------------  -----------
# # communities          50
# min community size      4
# max community size   4023
# avg. community size   558.34
# modularity              0.626548
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08347606658935547 [s]
# solution properties:
# -------------------  ----------
# # communities          48
# min community size      4
# max community size   4041
# avg. community size   581.604
# modularity              0.62498
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.09004426002502441 [s]
# solution properties:
# -------------------  -----------
# # communities          54
# min community size      4
# max community size   4002
# avg. community size   516.981
# modularity              0.625526
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08958101272583008 [s]
# solution properties:
# -------------------  ----------
# # communities          49
# min community size      4
# max community size   4105
# avg. community size   569.735
# modularity              0.62277
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.07301592826843262 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   3973
# avg. community size   581.604
# modularity              0.625652
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0801386833190918 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      3
# max community size   4169
# avg. community size   547.392
# modularity              0.622174
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06991815567016602 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4016
# avg. community size   581.604
# modularity              0.624715
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07086491584777832 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   4006
# avg. community size   634.477
# modularity              0.623815
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08262348175048828 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   3989
# avg. community size   620.378
# modularity              0.623519
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07421684265136719 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4131
# avg. community size   593.979
# modularity              0.625125
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0666201114654541 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4102
# avg. community size   547.392
# modularity              0.623862
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.11406731605529785 [s]
# solution properties:
# -------------------  ----------
# # communities          41
# min community size      4
# max community size   3839
# avg. community size   680.902
# modularity              0.62865
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0929574966430664 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4076
# avg. community size   593.979
# modularity              0.625838
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07239603996276855 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4100
# avg. community size   620.378
# modularity              0.626091
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.40267491340637207 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   3379
# avg. community size   634.477
# modularity              0.623298
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.15870022773742676 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      4
# max community size   4036
# avg. community size   649.233
# modularity              0.621646
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.11817646026611328 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      3
# max community size   3960
# avg. community size   649.233
# modularity              0.624352
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0579984188079834 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   4098
# avg. community size   680.902
# modularity              0.626807
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09254193305969238 [s]
# solution properties:
# -------------------  -----------
# # communities          52
# min community size      4
# max community size   3829
# avg. community size   536.865
# modularity              0.625956
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.10561203956604004 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      3
# max community size   3991
# avg. community size   569.735
# modularity              0.624251
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07119345664978027 [s]
# solution properties:
# -------------------  ----------
# # communities          46
# min community size      4
# max community size   4071
# avg. community size   606.891
# modularity              0.62425
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.06427717208862305 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   4025
# avg. community size   697.925
# modularity              0.624058
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06615853309631348 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4040
# avg. community size   581.604
# modularity              0.624414
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06227469444274902 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4021
# avg. community size   620.378
# modularity              0.624172
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0752108097076416 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   3993
# avg. community size   664.69
# modularity              0.625367
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0845797061920166 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3975
# avg. community size   606.891
# modularity              0.625888
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09343647956848145 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   3709
# avg. community size   569.735
# modularity              0.626679
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07097625732421875 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4093
# avg. community size   593.979
# modularity              0.624276
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.3473477363586426 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      3
# max community size   4336
# avg. community size   606.891
# modularity              0.621007
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09232759475708008 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4175
# avg. community size   620.378
# modularity              0.621337
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.058480024337768555 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   3966
# avg. community size   569.735
# modularity              0.624127
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06716394424438477 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   4363
# avg. community size   634.477
# modularity              0.620975
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06481146812438965 [s]
# solution properties:
# -------------------  -----------
# # communities          50
# min community size      4
# max community size   4001
# avg. community size   558.34
# modularity              0.626709
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.10132455825805664 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   3900
# avg. community size   581.604
# modularity              0.626425
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.1876683235168457 [s]
# solution properties:
# -------------------  ----------
# # communities          51
# min community size      4
# max community size   4024
# avg. community size   547.392
# modularity              0.62595
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.10454010963439941 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3959
# avg. community size   606.891
# modularity              0.626687
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07301855087280273 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   4086
# avg. community size   569.735
# modularity              0.623921
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06121015548706055 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      4
# max community size   3989
# avg. community size   649.233
# modularity              0.624172
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07315850257873535 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4096
# avg. community size   547.392
# modularity              0.625558
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06696009635925293 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4041
# avg. community size   620.378
# modularity              0.622437
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09811735153198242 [s]
# solution properties:
# -------------------  ----------
# # communities          51
# min community size      4
# max community size   3893
# avg. community size   547.392
# modularity              0.62506
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.20641326904296875 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3913
# avg. community size   606.891
# modularity              0.624328
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08738183975219727 [s]
# solution properties:
# -------------------  ----------
# # communities          50
# min community size      4
# max community size   4111
# avg. community size   558.34
# modularity              0.62568
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.06570625305175781 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      4
# max community size   4006
# avg. community size   649.233
# modularity              0.624616
# -------------------  -----------
# 112 ms ± 21.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## louvian method

# %%
# %timeit louvian_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.061625003814697266 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4205
# avg. community size   581.604
# modularity              0.626592
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08543705940246582 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   3892
# avg. community size   593.979
# modularity              0.625297
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0809621810913086 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   4048
# avg. community size   634.477
# modularity              0.626927
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07397150993347168 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   3964
# avg. community size   797.629
# modularity              0.622739
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.12009000778198242 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   3944
# avg. community size   593.979
# modularity              0.624458
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.1111602783203125 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   3917
# avg. community size   593.979
# modularity              0.625665
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09510326385498047 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3989
# avg. community size   606.891
# modularity              0.625194
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0641181468963623 [s]
# solution properties:
# -------------------  -----------
# # communities          53
# min community size      3
# max community size   4258
# avg. community size   526.736
# modularity              0.622833
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09344768524169922 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      3
# max community size   4092
# avg. community size   649.233
# modularity              0.624391
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06600069999694824 [s]
# solution properties:
# -------------------  ----------
# # communities          42
# min community size      4
# max community size   4033
# avg. community size   664.69
# modularity              0.62475
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.06264162063598633 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4156
# avg. community size   547.392
# modularity              0.626172
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07248473167419434 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   3803
# avg. community size   697.925
# modularity              0.624156
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07790398597717285 [s]
# solution properties:
# -------------------  -----------
# # communities          52
# min community size      3
# max community size   4178
# avg. community size   536.865
# modularity              0.624217
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.10096549987792969 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4015
# avg. community size   547.392
# modularity              0.624475
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.1039271354675293 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   3975
# avg. community size   634.477
# modularity              0.625508
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0641167163848877 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4046
# avg. community size   606.891
# modularity              0.625884
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.10648846626281738 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      4
# max community size   3961
# avg. community size   715.821
# modularity              0.626496
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09818291664123535 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4007
# avg. community size   593.979
# modularity              0.626749
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08407759666442871 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4014
# avg. community size   581.604
# modularity              0.623116
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06026148796081543 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      4
# max community size   4097
# avg. community size   715.821
# modularity              0.626614
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07581830024719238 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   3978
# avg. community size   593.979
# modularity              0.625355
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.09634041786193848 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   3840
# avg. community size   569.735
# modularity              0.623623
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07772564888000488 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   4051
# avg. community size   697.925
# modularity              0.622644
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06761693954467773 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   3981
# avg. community size   634.477
# modularity              0.625207
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0831916332244873 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4026
# avg. community size   593.979
# modularity              0.626311
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06271791458129883 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   3975
# avg. community size   581.604
# modularity              0.627599
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0624537467956543 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   4110
# avg. community size   734.658
# modularity              0.624347
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05852222442626953 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   4034
# avg. community size   569.735
# modularity              0.623331
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06412768363952637 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4092
# avg. community size   547.392
# modularity              0.623911
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06022191047668457 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4049
# avg. community size   593.979
# modularity              0.624725
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07985210418701172 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   3966
# avg. community size   680.902
# modularity              0.625452
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0642397403717041 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   3974
# avg. community size   634.477
# modularity              0.624308
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0641183853149414 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4097
# avg. community size   606.891
# modularity              0.625764
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0558929443359375 [s]
# solution properties:
# -------------------  ---------
# # communities          41
# min community size      4
# max community size   4014
# avg. community size   680.902
# modularity              0.6245
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.05849170684814453 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4240
# avg. community size   547.392
# modularity              0.624291
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06342220306396484 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4053
# avg. community size   606.891
# modularity              0.625201
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06098437309265137 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4179
# avg. community size   593.979
# modularity              0.625678
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06533527374267578 [s]
# solution properties:
# -------------------  -----------
# # communities          44
# min community size      4
# max community size   3839
# avg. community size   634.477
# modularity              0.624421
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05612063407897949 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4049
# avg. community size   606.891
# modularity              0.623091
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06629204750061035 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   3647
# avg. community size   697.925
# modularity              0.623872
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06843328475952148 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   4051
# avg. community size   664.69
# modularity              0.627357
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06763911247253418 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      4
# max community size   3741
# avg. community size   649.233
# modularity              0.624326
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07650995254516602 [s]
# solution properties:
# -------------------  -----------
# # communities          52
# min community size      4
# max community size   4020
# avg. community size   536.865
# modularity              0.624427
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06844544410705566 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      4
# max community size   4044
# avg. community size   569.735
# modularity              0.624277
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.060727596282958984 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4244
# avg. community size   606.891
# modularity              0.624456
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06330680847167969 [s]
# solution properties:
# -------------------  -----------
# # communities          53
# min community size      4
# max community size   4091
# avg. community size   526.736
# modularity              0.624124
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06003117561340332 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   4060
# avg. community size   664.69
# modularity              0.625763
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06160545349121094 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4054
# avg. community size   581.604
# modularity              0.624963
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.054341793060302734 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4040
# avg. community size   581.604
# modularity              0.624276
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0642385482788086 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4052
# avg. community size   606.891
# modularity              0.625414
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07556653022766113 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4007
# avg. community size   606.891
# modularity              0.624375
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05629992485046387 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4152
# avg. community size   620.378
# modularity              0.624688
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06415462493896484 [s]
# solution properties:
# -------------------  ----------
# # communities          48
# min community size      4
# max community size   4035
# avg. community size   581.604
# modularity              0.62413
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.06289267539978027 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4105
# avg. community size   581.604
# modularity              0.624927
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06928658485412598 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4252
# avg. community size   581.604
# modularity              0.623079
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06375622749328613 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   3915
# avg. community size   620.378
# modularity              0.625017
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07059359550476074 [s]
# solution properties:
# -------------------  -----------
# # communities          54
# min community size      3
# max community size   4219
# avg. community size   516.981
# modularity              0.623319
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06264114379882812 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3964
# avg. community size   606.891
# modularity              0.622486
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06883120536804199 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   3859
# avg. community size   581.604
# modularity              0.624053
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06845855712890625 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      3
# max community size   4036
# avg. community size   547.392
# modularity              0.623202
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06054353713989258 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   4069
# avg. community size   680.902
# modularity              0.624722
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06970047950744629 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4043
# avg. community size   581.604
# modularity              0.626451
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.10379600524902344 [s]
# solution properties:
# -------------------  ---------
# # communities          44
# min community size      4
# max community size   4040
# avg. community size   634.477
# modularity              0.6249
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.06547880172729492 [s]
# solution properties:
# -------------------  ----------
# # communities          46
# min community size      4
# max community size   3988
# avg. community size   606.891
# modularity              0.62637
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.060408592224121094 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   3785
# avg. community size   606.891
# modularity              0.625501
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0916745662689209 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      4
# max community size   4117
# avg. community size   606.891
# modularity              0.622786
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05882620811462402 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   3985
# avg. community size   664.69
# modularity              0.625478
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08263754844665527 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4065
# avg. community size   593.979
# modularity              0.623783
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06753730773925781 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      4
# max community size   3854
# avg. community size   649.233
# modularity              0.623456
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.060585975646972656 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4076
# avg. community size   593.979
# modularity              0.623119
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06569218635559082 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4037
# avg. community size   581.604
# modularity              0.623759
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.07257080078125 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   3809
# avg. community size   697.925
# modularity              0.624781
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0621790885925293 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4180
# avg. community size   593.979
# modularity              0.625623
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06144404411315918 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      4
# max community size   4016
# avg. community size   593.979
# modularity              0.624173
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.056525468826293945 [s]
# solution properties:
# -------------------  -----------
# # communities          50
# min community size      4
# max community size   4125
# avg. community size   558.34
# modularity              0.623475
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06766986846923828 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   3914
# avg. community size   581.604
# modularity              0.622889
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06798410415649414 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      4
# max community size   4054
# avg. community size   620.378
# modularity              0.625484
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06214261054992676 [s]
# solution properties:
# -------------------  -----------
# # communities          48
# min community size      4
# max community size   4004
# avg. community size   581.604
# modularity              0.624254
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08782315254211426 [s]
# solution properties:
# -------------------  -----------
# # communities          51
# min community size      4
# max community size   4075
# avg. community size   547.392
# modularity              0.624386
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0664365291595459 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   3968
# avg. community size   664.69
# modularity              0.623291
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.08397531509399414 [s]
# solution properties:
# -------------------  -----------
# # communities          42
# min community size      4
# max community size   3811
# avg. community size   664.69
# modularity              0.626265
# -------------------  -----------
# 75.7 ms ± 6.87 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # centralities

# %% [markdown]
# ## closeness

# %%
# %timeit closeness_centrality = nk.centrality.Closeness(G_nk, False, nk.centrality.ClosenessVariant.Generalized)
# Out:
# 272 ns ± 9.59 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit closeness_centrality = gt.closeness(G_gt)
# Out:
# 1min 55s ± 1.08 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## degree

# %%
# %timeit degree_centrality = nk.centrality.DegreeCentrality(G_nk)
# Out:
# 201 ns ± 9.74 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## eigen vector

# %%
# %timeit eigen_centrality = nk.centrality.EigenvectorCentrality(G_nk)
# Out:
# 204 ns ± 20.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit eigen_centrality = gt.eigenvector(G_gt)
# Out:
# 45.1 ms ± 7.03 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## page rank

# %%
# %timeit page_rank_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 203 ns ± 4.02 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit page_rank_centrality = gt.pagerank(G_gt)
# Out:
# 55.3 ms ± 2.05 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## katz

# %%
# %timeit katz_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 196 ns ± 3.64 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit katz_centrality = gt.katz(G_gt)
# Out:
# 183 ms ± 4.53 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## HITS

# %%
# %timeit hits_centrality = gt.hits(G_gt)
# Out:
# 67.5 ms ± 1.35 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
