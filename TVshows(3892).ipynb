# %%
import networkit as nk
import graph_tool.all as gt
import networkx as nx

import powerlaw
import matplotlib.pyplot as plt

from plots import Plots
from tools import values_frequency
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# ## load

# %%
snapReader = nk.graphio.SNAPGraphReader(False, False)
G_nk = snapReader.read("data/facebook_clean_data/tvshow_edges.csv")

# %%
G_gt = gt.load_graph_from_csv("data/facebook_clean_data/tvshow_edges.csv", csv_options={"delimiter": " "})

# %% [markdown]
# ## topology parameters

# %%
degrees = [G_nk.degree(v) for v in G_nk.iterNodes()]
degree_distr = sorted(nk.centrality.DegreeCentrality(G_nk).run().scores(), reverse=True)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_nk.numberOfNodes()))
print('number of edges: {}'.format(G_nk.numberOfEdges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 3892
# number of edges: 17262
# min degree: 1
# max degree: 126
# average degree: 8.86459403905447
# ----------------------------------------------------------------
# estimated gamma: 2.8388020140494943
# Calculating best minimal value for power law fit
# /home/sahar/Documents/NetworkAnalysis/venv/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /

# %%
degrees = G_gt.get_total_degrees(G_gt.get_vertices())
degree_distr, freq = values_frequency(degrees)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_gt.num_vertices()))
print('number of edges: {}'.format(G_gt.num_edges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 3892
# number of edges: 17262
# min degree: 1
# max degree: 126
# average degree: 8.870503597122303
# ----------------------------------------------------------------
# estimated gamma: 4.390371950497002
# Calculating best minimal value for power law fit

# %% [markdown]
# ## graph density

# %%
# %time
graph_density = G_nk.numberOfEdges() / ((G_nk.numberOfNodes()*(G_nk.numberOfNodes()-1))/2)
print('the graph density equals: {}'.format(graph_density))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.63 µs
# the graph density equals: 0.0022797490611982272

# %% [markdown]
# ## clustering coefficient

# %%
# %time
clustering_coefficient = nk.globals.clustering(G_nk)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient))
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.82 µs
# the clustering coefficient of the graph equals: 0.4454963953791366

# %%
# %time
clustering_coefficient = gt.global_clustering(G_gt)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient[0]))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 9.54 µs
# the clustering coefficient of the graph equals: 0.5906435656994041

# %% [markdown]
# ## assortativity

# %%
# %time
G_nx = nk.nxadapter.nk2nx(G_nk)
assortativity = nx.degree_assortativity_coefficient(G_nx)
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# assortativity coefficient is: 0.560355401968808

# %%
# %time
assortativity = gt.assortativity(G_gt, "total")
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 4.77 µs
# assortativity coefficient is: (0.03714234619711491, 0.0018102616295243511)

# %% [markdown]
# # community detection

# %% [markdown]
# ## label propagation

# %%
# %timeit label_prop_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.03041696548461914 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872008
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02371692657470703 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.87216
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0035390853881835938 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871954
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010919570922851562 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872092
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01981353759765625 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871808
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009573936462402344 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.872091
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008937358856201172 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   265
# avg. community size   82.8085
# modularity             0.872038
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033435821533203125 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.87194
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0038666725158691406 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872226
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031251907348632812 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872175
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003354787826538086 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872212
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002906322479248047 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872021
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01956343650817871 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872122
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04477715492248535 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872149
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.03974318504333496 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   288
# avg. community size   82.8085
# modularity             0.871842
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.07952237129211426 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     7
# max community size   272
# avg. community size   82.8085
# modularity             0.872148
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031194686889648438 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871999
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00850534439086914 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005408048629760742 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872377
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0241396427154541 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   264
# avg. community size   86.4889
# modularity             0.871903
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0047168731689453125 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872303
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.021625995635986328 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   260
# avg. community size   84.6087
# modularity             0.872401
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005707263946533203 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   269
# avg. community size   82.8085
# modularity             0.872219
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010279417037963867 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   261
# avg. community size   82.8085
# modularity             0.872004
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013705968856811523 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871948
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009639501571655273 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     8
# max community size   278
# avg. community size   79.4286
# modularity             0.871979
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005689144134521484 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872133
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031976699829101562 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872055
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002871990203857422 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872021
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003240823745727539 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872047
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0026443004608154297 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002727031707763672 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872211
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032019615173339844 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   287
# avg. community size   81.0833
# modularity             0.87178
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0034847259521484375 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871952
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028808116912841797 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   265
# avg. community size   81.0833
# modularity             0.872154
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029451847076416016 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   294
# avg. community size   86.4889
# modularity             0.872305
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002898693084716797 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872196
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027251243591308594 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002953052520751953 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871756
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031158924102783203 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   293
# avg. community size   82.8085
# modularity             0.871841
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028002262115478516 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872256
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003631591796875 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872154
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004607677459716797 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871987
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002800464630126953 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871672
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00819253921508789 [s]
# solution properties:
# -------------------  ----------
# # communities         50
# min community size     8
# max community size   261
# avg. community size   77.84
# modularity             0.871793
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002882719039916992 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872118
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003127574920654297 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872349
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030574798583984375 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   268
# avg. community size   81.0833
# modularity             0.872042
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003093719482421875 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872047
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003193378448486328 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871938
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029282569885253906 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872247
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01932358741760254 [s]
# solution properties:
# -------------------  ---------
# # communities         45
# min community size     8
# max community size   289
# avg. community size   86.4889
# modularity             0.87215
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003361225128173828 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   290
# avg. community size   86.4889
# modularity             0.871519
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003448009490966797 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871903
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00867915153503418 [s]
# solution properties:
# -------------------  --------
# # communities         44
# min community size     8
# max community size   265
# avg. community size   88.4545
# modularity             0.8722
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.0030732154846191406 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   273
# avg. community size   81.0833
# modularity             0.87163
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0030341148376464844 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871899
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.014262199401855469 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872138
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.006706714630126953 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871949
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033774375915527344 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   298
# avg. community size   84.6087
# modularity             0.871956
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003351449966430664 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872057
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0038826465606689453 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   268
# avg. community size   82.8085
# modularity             0.871706
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003020048141479492 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   292
# avg. community size   84.6087
# modularity             0.87233
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0031099319458007812 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872192
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028581619262695312 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872036
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028061866760253906 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002766847610473633 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871981
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030891895294189453 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872054
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002913236618041992 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   282
# avg. community size   86.4889
# modularity             0.872228
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002772808074951172 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.872155
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028688907623291016 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871734
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029807090759277344 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871949
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027790069580078125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872273
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002919912338256836 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872173
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02477550506591797 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   292
# avg. community size   86.4889
# modularity             0.872233
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027573108673095703 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871922
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0035123825073242188 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872068
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030291080474853516 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872252
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029883384704589844 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872278
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032596588134765625 [s]
# solution properties:
# -------------------  ----------
# # communities         41
# min community size    14
# max community size   304
# avg. community size   94.9268
# modularity             0.871984
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002962350845336914 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.87202
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.012497425079345703 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871774
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003817319869995117 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   263
# avg. community size   86.4889
# modularity             0.872269
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004046440124511719 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871844
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003688335418701172 [s]
# solution properties:
# -------------------  ----------
# # communities         44
# min community size     8
# max community size   295
# avg. community size   88.4545
# modularity             0.871999
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00529789924621582 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     7
# max community size   318
# avg. community size   79.4286
# modularity             0.870858
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003092527389526367 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003077983856201172 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872125
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003207683563232422 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     7
# max community size   284
# avg. community size   79.4286
# modularity             0.871894
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031239986419677734 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   292
# avg. community size   86.4889
# modularity             0.872345
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029859542846679688 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872256
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002887725830078125 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     7
# max community size   289
# avg. community size   79.4286
# modularity             0.871989
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028455257415771484 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872266
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003110170364379883 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   289
# avg. community size   81.0833
# modularity             0.871831
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0034055709838867188 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   293
# avg. community size   84.6087
# modularity             0.871259
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029556751251220703 [s]
# solution properties:
# -------------------  ----------
# # communities         50
# min community size     7
# max community size   289
# avg. community size   77.84
# modularity             0.872096
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028998851776123047 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   258
# avg. community size   82.8085
# modularity             0.871875
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030317306518554688 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871899
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003476381301879883 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   299
# avg. community size   84.6087
# modularity             0.871769
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031151771545410156 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872003
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029273033142089844 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871783
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002897977828979492 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871859
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031402111053466797 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   289
# avg. community size   86.4889
# modularity             0.872293
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027611255645751953 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.87189
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.002965688705444336 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872144
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003011941909790039 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   290
# avg. community size   82.8085
# modularity             0.871931
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01839900016784668 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   281
# avg. community size   86.4889
# modularity             0.872211
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0043582916259765625 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872039
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004818916320800781 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   259
# avg. community size   82.8085
# modularity             0.872286
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003095865249633789 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   273
# avg. community size   82.8085
# modularity             0.871686
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002922534942626953 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.87189
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0033812522888183594 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.87189
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0026803016662597656 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872009
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00566554069519043 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   260
# avg. community size   81.0833
# modularity             0.871933
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003633260726928711 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   294
# avg. community size   86.4889
# modularity             0.872329
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029816627502441406 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871985
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029125213623046875 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871981
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027832984924316406 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01736927032470703 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   289
# avg. community size   82.8085
# modularity             0.871942
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004559755325317383 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871909
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0036606788635253906 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872008
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00316619873046875 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871969
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003942251205444336 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   286
# avg. community size   84.6087
# modularity             0.872042
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030374526977539062 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871949
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003090381622314453 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028276443481445312 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872159
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002808094024658203 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871895
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002793550491333008 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872175
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030074119567871094 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872269
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029735565185546875 [s]
# solution properties:
# -------------------  ----------
# # communities         43
# min community size    16
# max community size   263
# avg. community size   90.5116
# modularity             0.871865
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003343343734741211 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871864
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003098011016845703 [s]
# solution properties:
# -------------------  ---------
# # communities         45
# min community size     8
# max community size   267
# avg. community size   86.4889
# modularity             0.87208
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0030584335327148438 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872169
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003072500228881836 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   292
# avg. community size   82.8085
# modularity             0.871786
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002869129180908203 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   286
# avg. community size   86.4889
# modularity             0.871986
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002656221389770508 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030241012573242188 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871902
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031366348266601562 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871827
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002851247787475586 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872072
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027675628662109375 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871918
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029680728912353516 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.87195
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0032112598419189453 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.87191
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003136157989501953 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872105
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003129720687866211 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871642
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003168344497680664 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872151
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.018889665603637695 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004756927490234375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   263
# avg. community size   82.8085
# modularity             0.871917
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003677845001220703 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size    10
# max community size   262
# avg. community size   86.4889
# modularity             0.871902
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01093435287475586 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872097
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003286123275756836 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   265
# avg. community size   84.6087
# modularity             0.872062
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003249645233154297 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872123
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01294851303100586 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872228
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.014379739761352539 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871716
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.012908697128295898 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   261
# avg. community size   84.6087
# modularity             0.87168
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.005726337432861328 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872008
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.007030010223388672 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.87201
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.00826716423034668 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   262
# avg. community size   81.0833
# modularity             0.872081
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004936695098876953 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   273
# avg. community size   84.6087
# modularity             0.871729
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028829574584960938 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     8
# max community size   264
# avg. community size   79.4286
# modularity             0.871909
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002935647964477539 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872123
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032465457916259766 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   267
# avg. community size   84.6087
# modularity             0.871911
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032465457916259766 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     7
# max community size   287
# avg. community size   79.4286
# modularity             0.872134
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0076427459716796875 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   272
# avg. community size   82.8085
# modularity             0.87195
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003117799758911133 [s]
# solution properties:
# ...
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004964351654052734 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.007665872573852539 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.87216
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0029516220092773438 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872003
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0026895999908447266 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871836
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002931833267211914 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872151
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0026607513427734375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872008
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030879974365234375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031325817108154297 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   269
# avg. community size   81.0833
# modularity             0.872011
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003126382827758789 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.872093
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029973983764648438 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871818
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002783060073852539 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   263
# avg. community size   82.8085
# modularity             0.872119
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031807422637939453 [s]
# solution properties:
# -------------------  ----------
# # communities         44
# min community size     8
# max community size   290
# avg. community size   88.4545
# modularity             0.872171
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003387451171875 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872017
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028519630432128906 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   271
# avg. community size   86.4889
# modularity             0.872426
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031108856201171875 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871901
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031020641326904297 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872069
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032019615173339844 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.872202
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0026946067810058594 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871571
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031554698944091797 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872201
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002681255340576172 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871812
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002834320068359375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871926
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031807422637939453 [s]
# solution properties:
# -------------------  ----------
# # communities         43
# min community size     8
# max community size   271
# avg. community size   90.5116
# modularity             0.872495
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027866363525390625 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.87188
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.002859830856323242 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.87201
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0028967857360839844 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   271
# avg. community size   86.4889
# modularity             0.872545
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002885103225708008 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   260
# avg. community size   81.0833
# modularity             0.872269
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032715797424316406 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   258
# avg. community size   84.6087
# modularity             0.871949
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003423929214477539 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872117
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003232240676879883 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   268
# avg. community size   84.6087
# modularity             0.871957
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027494430541992188 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871836
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029287338256835938 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.87213
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0033152103424072266 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   265
# avg. community size   81.0833
# modularity             0.872007
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002952098846435547 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872133
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028274059295654297 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.87229
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0031609535217285156 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871816
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031442642211914062 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   288
# avg. community size   81.0833
# modularity             0.872003
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003018617630004883 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   271
# avg. community size   86.4889
# modularity             0.872496
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0026645660400390625 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027930736541748047 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871907
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033004283905029297 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.87202
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.002744913101196289 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   292
# avg. community size   84.6087
# modularity             0.872058
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0026683807373046875 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871812
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.025803327560424805 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872223
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003347158432006836 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872004
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002863168716430664 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   264
# avg. community size   86.4889
# modularity             0.871725
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003470182418823242 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872026
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004303693771362305 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872229
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0036890506744384766 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   291
# avg. community size   82.8085
# modularity             0.872092
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030655860900878906 [s]
# solution properties:
# -------------------  --------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.0027430057525634766 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871687
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00264739990234375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871961
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002821683883666992 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871958
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028715133666992188 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   265
# avg. community size   84.6087
# modularity             0.872237
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029115676879882812 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size    10
# max community size   263
# avg. community size   81.0833
# modularity             0.871781
# -------------------  ----------
# 5.54 ms ± 376 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## louvian method

# %%
# %timeit louvian_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.0050160884857177734 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   262
# avg. community size   82.8085
# modularity             0.872215
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01501154899597168 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0057070255279541016 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872045
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.006412506103515625 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871991
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030219554901123047 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871717
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033702850341796875 [s]
# solution properties:
# -------------------  ----------
# # communities         44
# min community size     8
# max community size   292
# avg. community size   88.4545
# modularity             0.871696
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031633377075195312 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   284
# avg. community size   82.8085
# modularity             0.871841
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029516220092773438 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871871
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003187894821166992 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872175
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002892017364501953 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871841
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031952857971191406 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   294
# avg. community size   82.8085
# modularity             0.872298
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029447078704833984 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002821207046508789 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871957
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003036022186279297 [s]
# solution properties:
# -------------------  ----------
# # communities         44
# min community size     8
# max community size   277
# avg. community size   88.4545
# modularity             0.872063
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029447078704833984 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   261
# avg. community size   84.6087
# modularity             0.871626
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002888202667236328 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872019
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031981468200683594 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871893
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029332637786865234 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   267
# avg. community size   82.8085
# modularity             0.872042
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002901792526245117 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872294
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033044815063476562 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872175
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029993057250976562 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872133
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00318145751953125 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.87187
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003142118453979492 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871961
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003040790557861328 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871971
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029518604278564453 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872107
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002952098846435547 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872192
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.021932363510131836 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872089
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.1294722557067871 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   262
# avg. community size   84.6087
# modularity             0.87187
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.011956453323364258 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872149
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005048274993896484 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872106
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.019829750061035156 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   268
# avg. community size   86.4889
# modularity             0.871546
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003889799118041992 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871903
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0038640499114990234 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   265
# avg. community size   84.6087
# modularity             0.872433
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010817527770996094 [s]
# solution properties:
# -------------------  ---------
# # communities         45
# min community size     8
# max community size   260
# avg. community size   86.4889
# modularity             0.87242
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.009127378463745117 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   297
# avg. community size   82.8085
# modularity             0.871668
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005067348480224609 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872204
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003533601760864258 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003309488296508789 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872017
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003175497055053711 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003062725067138672 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872144
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002857208251953125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871847
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030922889709472656 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   290
# avg. community size   82.8085
# modularity             0.872011
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002964019775390625 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871892
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028142929077148438 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871961
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002992391586303711 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871943
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032835006713867188 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   265
# avg. community size   82.8085
# modularity             0.872445
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028908252716064453 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872102
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00289154052734375 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872009
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.015086650848388672 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871961
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.006127357482910156 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871803
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0036721229553222656 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872149
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003049135208129883 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005865335464477539 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   273
# avg. community size   82.8085
# modularity             0.871879
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0034987926483154297 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size    10
# max community size   264
# avg. community size   86.4889
# modularity             0.872099
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028684139251708984 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   290
# avg. community size   84.6087
# modularity             0.872239
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.017493247985839844 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   286
# avg. community size   86.4889
# modularity             0.872261
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005600690841674805 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871967
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031061172485351562 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872247
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031495094299316406 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872025
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031049251556396484 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003726482391357422 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   269
# avg. community size   84.6087
# modularity             0.872104
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003047466278076172 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871922
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030198097229003906 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003076791763305664 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   266
# avg. community size   86.4889
# modularity             0.871737
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0035610198974609375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872327
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029397010803222656 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871836
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028638839721679688 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871927
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032296180725097656 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872116
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031418800354003906 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   258
# avg. community size   81.0833
# modularity             0.87193
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003286600112915039 [s]
# solution properties:
# -------------------  ----------
# # communities         43
# min community size     8
# max community size   298
# avg. community size   90.5116
# modularity             0.871998
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002922534942626953 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   265
# avg. community size   82.8085
# modularity             0.87237
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.002973318099975586 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   263
# avg. community size   81.0833
# modularity             0.871989
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028574466705322266 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.87199
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003060579299926758 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   295
# avg. community size   84.6087
# modularity             0.872458
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033299922943115234 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   258
# avg. community size   81.0833
# modularity             0.872176
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030329227447509766 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871866
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003088712692260742 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871959
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031871795654296875 [s]
# solution properties:
# -------------------  ----------
# # communities         44
# min community size    10
# max community size   264
# avg. community size   88.4545
# modularity             0.872135
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029985904693603516 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872177
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030243396759033203 [s]
# solution properties:
# -------------------  --------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.0027959346771240234 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872026
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00366973876953125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   285
# avg. community size   84.6087
# modularity             0.872312
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003484964370727539 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872056
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029840469360351562 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871975
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003015756607055664 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872149
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0034797191619873047 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   263
# avg. community size   84.6087
# modularity             0.872099
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002961397171020508 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871838
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028967857360839844 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   264
# avg. community size   86.4889
# modularity             0.871625
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003161191940307617 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871787
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003009796142578125 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872141
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0035011768341064453 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   276
# avg. community size   86.4889
# modularity             0.872294
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030095577239990234 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   292
# avg. community size   84.6087
# modularity             0.871958
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.022620677947998047 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872008
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.015127420425415039 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   259
# avg. community size   82.8085
# modularity             0.871981
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005572795867919922 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   273
# avg. community size   82.8085
# modularity             0.871557
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029668807983398438 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005658149719238281 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871993
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033266544342041016 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.87195
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003506183624267578 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   274
# avg. community size   84.6087
# modularity             0.872351
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031578540802001953 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871858
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002983570098876953 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872025
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003026247024536133 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   261
# avg. community size   81.0833
# modularity             0.87199
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0028781890869140625 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871926
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003106355667114258 [s]
# solution properties:
# -------------------  ----------
# # communities         49
# min community size     8
# max community size   265
# avg. community size   79.4286
# modularity             0.871965
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029981136322021484 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size    10
# max community size   266
# avg. community size   84.6087
# modularity             0.871925
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003326892852783203 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872075
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003007173538208008 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size    10
# max community size   266
# avg. community size   84.6087
# modularity             0.871826
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030040740966796875 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   265
# avg. community size   84.6087
# modularity             0.872324
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028533935546875 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872004
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032999515533447266 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   261
# avg. community size   82.8085
# modularity             0.872021
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030486583709716797 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871923
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002935647964477539 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872181
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030095577239990234 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872121
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00299835205078125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872067
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031108856201171875 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   273
# avg. community size   86.4889
# modularity             0.871515
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030367374420166016 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size    10
# max community size   264
# avg. community size   84.6087
# modularity             0.872004
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002931356430053711 [s]
# solution properties:
# -------------------  ----------
# # communities         43
# min community size     8
# max community size   284
# avg. community size   90.5116
# modularity             0.872339
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002906322479248047 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   261
# avg. community size   81.0833
# modularity             0.872201
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003384113311767578 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   260
# avg. community size   82.8085
# modularity             0.871996
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003301382064819336 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   284
# avg. community size   82.8085
# modularity             0.872204
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002996206283569336 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.872065
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002997159957885742 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872243
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032815933227539062 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871941
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002987384796142578 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002877950668334961 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872063
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030679702758789062 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   293
# avg. community size   81.0833
# modularity             0.871909
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0034041404724121094 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   288
# avg. community size   82.8085
# modularity             0.871887
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030536651611328125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size    10
# max community size   269
# avg. community size   84.6087
# modularity             0.871531
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029141902923583984 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   261
# avg. community size   81.0833
# modularity             0.871881
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028612613677978516 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871892
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003005504608154297 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   261
# avg. community size   81.0833
# modularity             0.871758
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003016233444213867 [s]
# solution properties:
# -------------------  --------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.003022432327270508 [s]
# solution properties:
# -------------------  ----------
# # communities         50
# min community size     8
# max community size   261
# avg. community size   77.84
# modularity             0.872034
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003064393997192383 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871836
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033762454986572266 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   268
# avg. community size   81.0833
# modularity             0.871909
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031876564025878906 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   263
# avg. community size   82.8085
# modularity             0.872651
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003014087677001953 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   261
# avg. community size   84.6087
# modularity             0.871959
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028412342071533203 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003563404083251953 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872068
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0234067440032959 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872128
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003185749053955078 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   291
# avg. community size   81.0833
# modularity             0.872011
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0035524368286132812 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871959
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003019571304321289 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   279
# avg. community size   86.4889
# modularity             0.872187
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0038237571716308594 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0055959224700927734 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871908
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003565549850463867 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872105
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003317594528198242 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   273
# avg. community size   82.8085
# modularity             0.871675
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032033920288085938 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872021
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003400087356567383 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871838
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033791065216064453 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872074
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003119230270385742 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   285
# avg. community size   84.6087
# modularity             0.871976
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030622482299804688 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   264
# avg. community size   86.4889
# modularity             0.871995
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002897500991821289 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   258
# avg. community size   82.8085
# modularity             0.871878
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033447742462158203 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872144
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002874135971069336 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871908
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003002166748046875 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872128
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002962827682495117 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872025
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032727718353271484 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872183
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003106355667114258 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872008
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0036001205444335938 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.87228
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0029489994049072266 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871948
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032806396484375 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871922
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003040790557861328 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872243
# -------------------  ----------
# ...
# modularity             0.871804
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002737760543823242 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871954
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033991336822509766 [s]
# solution properties:
# -------------------  ----------
# # communities         50
# min community size     8
# max community size   261
# avg. community size   77.84
# modularity             0.871849
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028619766235351562 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.023491621017456055 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871704
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032858848571777344 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872141
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033817291259765625 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871735
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031211376190185547 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871966
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0037147998809814453 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872184
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005430936813354492 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872088
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003018617630004883 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0029091835021972656 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003054380416870117 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872098
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031261444091796875 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.87176
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0028734207153320312 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871961
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028853416442871094 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872296
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028586387634277344 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871923
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028443336486816406 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   268
# avg. community size   86.4889
# modularity             0.872193
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002902984619140625 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871934
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003063678741455078 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872256
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002940654754638672 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871611
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028600692749023438 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871872
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031125545501708984 [s]
# solution properties:
# -------------------  --------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.0034689903259277344 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872305
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003064870834350586 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   263
# avg. community size   82.8085
# modularity             0.872119
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003589630126953125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872096
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003245115280151367 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.871939
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002890348434448242 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871836
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00286865234375 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871944
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028519630432128906 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871949
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028772354125976562 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872021
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0027484893798828125 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.871922
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0030052661895751953 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.872144
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002825498580932617 [s]
# solution properties:
# -------------------  --------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.0029985904693603516 [s]
# solution properties:
# -------------------  ---------
# # communities         47
# min community size     8
# max community size   264
# avg. community size   82.8085
# modularity             0.87192
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.003803730010986328 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.87194
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0028409957885742188 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.872001
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002851724624633789 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871923
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0032057762145996094 [s]
# solution properties:
# -------------------  --------
# # communities         47
# min community size     8
# max community size   269
# avg. community size   82.8085
# modularity             0.8716
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.00299835205078125 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   266
# avg. community size   82.8085
# modularity             0.871923
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.003053426742553711 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.871954
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0028929710388183594 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   271
# avg. community size   81.0833
# modularity             0.871626
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0033431053161621094 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.87195
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0027933120727539062 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   264
# avg. community size   84.6087
# modularity             0.872017
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0035371780395507812 [s]
# solution properties:
# -------------------  ---------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.87226
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.0030944347381591797 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.871838
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.002879619598388672 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   264
# avg. community size   81.0833
# modularity             0.871935
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031571388244628906 [s]
# solution properties:
# -------------------  ----------
# # communities         46
# min community size     8
# max community size   266
# avg. community size   84.6087
# modularity             0.872226
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0031044483184814453 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872158
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.004230976104736328 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   290
# avg. community size   82.8085
# modularity             0.871829
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005969524383544922 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   275
# avg. community size   81.0833
# modularity             0.871941
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.007202625274658203 [s]
# solution properties:
# -------------------  ----------
# # communities         45
# min community size     8
# max community size   292
# avg. community size   86.4889
# modularity             0.872547
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.025949716567993164 [s]
# solution properties:
# -------------------  ----------
# # communities         47
# min community size     8
# max community size   290
# avg. community size   82.8085
# modularity             0.872169
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.005646467208862305 [s]
# solution properties:
# -------------------  ----------
# # communities         48
# min community size     8
# max community size   266
# avg. community size   81.0833
# modularity             0.872316
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.006572246551513672 [s]
# solution properties:
# -------------------  ---------
# # communities         46
# min community size     8
# max community size   274
# avg. community size   84.6087
# modularity             0.87259
# -------------------  ---------
# 4.71 ms ± 131 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # centralities

# %% [markdown]
# ## betweenness centrality

# %%
# %timeit btwn_centrality = nk.centrality.Betweenness(G_nk).run()
# Out:
# 2.03 s ± 6.04 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit btwn_centrality = gt.betweenness(G_gt)
# Out:
# 728 ms ± 12.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## closeness

# %%
# %timeit closeness_centrality = nk.centrality.Closeness(G_nk, False, nk.centrality.ClosenessVariant.Generalized)
# Out:
# 296 ns ± 27.5 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit closeness_centrality = gt.closeness(G_gt)
# Out:
# 1.03 s ± 29.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## degree

# %%
# %timeit degree_centrality = nk.centrality.DegreeCentrality(G_nk)
# Out:
# 207 ns ± 6.95 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## eigen vector

# %%
# %timeit eigen_centrality = nk.centrality.EigenvectorCentrality(G_nk)
# Out:
# 201 ns ± 2.13 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit eigen_centrality = gt.eigenvector(G_gt)
# Out:
# 1.99 ms ± 285 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## page rank

# %%
# %timeit page_rank_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 205 ns ± 5.39 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit page_rank_centrality = gt.pagerank(G_gt)
# Out:
# 2.93 ms ± 209 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## katz

# %%
# %timeit katz_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 211 ns ± 10.5 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit katz_centrality = gt.katz(G_gt)
# Out:
# 4.37 ms ± 188 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## HITS

# %%
# %timeit hits_centrality = gt.hits(G_gt)
# Out:
# 3.34 ms ± 293 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
