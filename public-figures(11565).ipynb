# %%
import networkit as nk
import graph_tool.all as gt
import networkx as nx

import powerlaw
import matplotlib.pyplot as plt

from plots import Plots
from tools import values_frequency
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# ## load

# %%
snapReader = nk.graphio.SNAPGraphReader(False, False)
G_nk = snapReader.read("data/facebook_clean_data/public_figure_edges.csv")

# %%
G_gt = gt.load_graph_from_csv("data/facebook_clean_data/public_figure_edges.csv", csv_options={"delimiter": " "})

# %% [markdown]
# ## topology parameters

# %%
degrees = [G_nk.degree(v) for v in G_nk.iterNodes()]
degree_distr = sorted(nk.centrality.DegreeCentrality(G_nk).run().scores(), reverse=True)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_nk.numberOfNodes()))
print('number of edges: {}'.format(G_nk.numberOfEdges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 11565
# number of edges: 67114
# min degree: 1
# max degree: 326
# average degree: 11.599827064418504
# ----------------------------------------------------------------
# estimated gamma: 2.4971785156569757
# Calculating best minimal value for power law fit
# /home/sahar/Documents/NetworkAnalysis/venv/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /

# %%
degrees = G_gt.get_total_degrees(G_gt.get_vertices())
degree_distr, freq = values_frequency(degrees)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_gt.num_vertices()))
print('number of edges: {}'.format(G_gt.num_edges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 11565
# number of edges: 67114
# min degree: 1
# max degree: 326
# average degree: 11.606398616515348
# ----------------------------------------------------------------
# estimated gamma: 7.392988690793513
# Calculating best minimal value for power law fit

# %% [markdown]
# ## graph density

# %%
# %time
graph_density = G_nk.numberOfEdges() / ((G_nk.numberOfNodes()*(G_nk.numberOfNodes()-1))/2)
print('the graph density equals: {}'.format(graph_density))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.25 µs
# the graph density equals: 0.001003666431729103

# %% [markdown]
# ## clustering coefficient

# %%
# %time
clustering_coefficient = nk.globals.clustering(G_nk)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient))
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.87 µs
# the clustering coefficient of the graph equals: 0.21388864761573873

# %%
# %time
clustering_coefficient = gt.global_clustering(G_gt)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient[0]))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.39 µs
# the clustering coefficient of the graph equals: 0.1665644876656779

# %% [markdown]
# ## assortativity

# %%
# %time
G_nx = nk.nxadapter.nk2nx(G_nk)
assortativity = nx.degree_assortativity_coefficient(G_nx)
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 7.87 µs
# assortativity coefficient is: 0.202161548290631

# %%
# %time
assortativity = gt.assortativity(G_gt, "total")
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.53 µs
# assortativity coefficient is: (0.00874265802241826, 0.0005564184360778624)

# %% [markdown]
# # community detection

# %% [markdown]
# ## label propagation

# %%
# %timeit label_prop_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.12117171287536621 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1711
# avg. community size   361.406
# modularity              0.682358
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.020938396453857422 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      4
# max community size   2022
# avg. community size   312.568
# modularity              0.683259
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.04743361473083496 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   2289
# avg. community size   282.073
# modularity              0.683099
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.035274505615234375 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   2391
# avg. community size   304.342
# modularity              0.677161
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0218813419342041 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      5
# max community size   1722
# avg. community size   312.568
# modularity              0.680911
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0217282772064209 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   2008
# avg. community size   340.147
# modularity              0.683466
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0587310791015625 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      4
# max community size   1857
# avg. community size   398.793
# modularity              0.679708
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.02070307731628418 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      5
# max community size   1477
# avg. community size   373.065
# modularity              0.681557
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014360666275024414 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1611
# avg. community size   361.406
# modularity              0.682551
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.024827241897583008 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   1783
# avg. community size   289.125
# modularity              0.682799
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.018413066864013672 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   1551
# avg. community size   350.455
# modularity              0.683486
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012720346450805664 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   2304
# avg. community size   304.342
# modularity              0.681939
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014199495315551758 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      5
# max community size   1921
# avg. community size   373.065
# modularity              0.680803
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.11973881721496582 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      4
# max community size   2124
# avg. community size   373.065
# modularity              0.681868
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.049341440200805664 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      5
# max community size   1579
# avg. community size   330.429
# modularity              0.684057
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.019606351852416992 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size      5
# max community size   1791
# avg. community size   428.333
# modularity              0.681993
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012256145477294922 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1680
# avg. community size   340.147
# modularity              0.683662
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013042449951171875 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   1912
# avg. community size   304.342
# modularity              0.682625
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014474153518676758 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   1940
# avg. community size   350.455
# modularity              0.682538
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012770414352416992 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      4
# max community size   1868
# avg. community size   361.406
# modularity              0.683427
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013226509094238281 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1931
# avg. community size   340.147
# modularity              0.683559
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012941598892211914 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   2349
# avg. community size   330.429
# modularity              0.679342
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014348030090332031 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      4
# max community size   1877
# avg. community size   373.065
# modularity              0.681547
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03610873222351074 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   2001
# avg. community size   350.455
# modularity              0.680252
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01840662956237793 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      4
# max community size   1939
# avg. community size   385.5
# modularity              0.681548
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01384878158569336 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1602
# avg. community size   340.147
# modularity              0.684429
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014527320861816406 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size      5
# max community size   1665
# avg. community size   413.036
# modularity              0.681471
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01308298110961914 [s]
# solution properties:
# -------------------  ----------
# # communities          32
# min community size      4
# max community size   1783
# avg. community size   361.406
# modularity              0.68213
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01230001449584961 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1956
# avg. community size   340.147
# modularity              0.679044
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013061046600341797 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   2152
# avg. community size   340.147
# modularity              0.676937
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015538930892944336 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      4
# max community size   1782
# avg. community size   385.5
# modularity              0.681637
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01543116569519043 [s]
# solution properties:
# -------------------  -----------
# # communities          43
# min community size      3
# max community size   2116
# avg. community size   268.953
# modularity              0.681004
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013859748840332031 [s]
# solution properties:
# -------------------  -----------
# # communities          50
# min community size      3
# max community size   2726
# avg. community size   231.3
# modularity              0.678278
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01737380027770996 [s]
# solution properties:
# -------------------  ----------
# # communities          28
# min community size      4
# max community size   1692
# avg. community size   413.036
# modularity              0.68235
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013921260833740234 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      5
# max community size   1696
# avg. community size   321.25
# modularity              0.683782
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03068685531616211 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      4
# max community size   1797
# avg. community size   321.25
# modularity              0.682243
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.018923521041870117 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   2059
# avg. community size   350.455
# modularity              0.682281
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013770818710327148 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   2231
# avg. community size   289.125
# modularity              0.681537
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014089107513427734 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   2108
# avg. community size   340.147
# modularity              0.680497
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013401269912719727 [s]
# solution properties:
# -------------------  -----------
# # communities          25
# min community size      5
# max community size   1478
# avg. community size   462.6
# modularity              0.684761
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014838695526123047 [s]
# solution properties:
# -------------------  -----------
# # communities          26
# min community size      5
# max community size   1820
# avg. community size   444.808
# modularity              0.680562
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014431238174438477 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   1991
# avg. community size   304.342
# modularity              0.682118
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.016094684600830078 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      5
# max community size   1969
# avg. community size   321.25
# modularity              0.681046
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.02201104164123535 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      5
# max community size   1675
# avg. community size   398.793
# modularity              0.683572
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014916419982910156 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1653
# avg. community size   361.406
# modularity              0.682119
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01259303092956543 [s]
# solution properties:
# -------------------  ----------
# # communities          26
# min community size      5
# max community size   1575
# avg. community size   444.808
# modularity              0.68256
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013216257095336914 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   1810
# avg. community size   304.342
# modularity              0.680745
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.018969297409057617 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size      5
# max community size   1464
# avg. community size   413.036
# modularity              0.680828
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014069318771362305 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      4
# max community size   2286
# avg. community size   321.25
# modularity              0.680249
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014566421508789062 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   1889
# avg. community size   304.342
# modularity              0.684893
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01577925682067871 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      4
# max community size   1771
# avg. community size   373.065
# modularity              0.682672
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012730836868286133 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   2031
# avg. community size   330.429
# modularity              0.683492
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013785839080810547 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      4
# max community size   2045
# avg. community size   373.065
# modularity              0.682216
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01274871826171875 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      3
# max community size   2423
# avg. community size   282.073
# modularity              0.679358
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013131380081176758 [s]
# solution properties:
# -------------------  -----------
# # communities          26
# min community size      5
# max community size   1879
# avg. community size   444.808
# modularity              0.681585
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015668392181396484 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      5
# max community size   1596
# avg. community size   321.25
# modularity              0.683411
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.011868476867675781 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1477
# avg. community size   340.147
# modularity              0.684494
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01373434066772461 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1510
# avg. community size   361.406
# modularity              0.684419
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.030597209930419922 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      4
# max community size   2512
# avg. community size   312.568
# modularity              0.683398
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01841282844543457 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      3
# max community size   2658
# avg. community size   251.413
# modularity              0.679797
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012578010559082031 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size      4
# max community size   1753
# avg. community size   428.333
# modularity              0.682618
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.033028602600097656 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size      5
# max community size   1729
# avg. community size   413.036
# modularity              0.682691
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013944149017333984 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1602
# avg. community size   340.147
# modularity              0.683235
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.018138408660888672 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      4
# max community size   2228
# avg. community size   321.25
# modularity              0.684683
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01704573631286621 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      5
# max community size   1548
# avg. community size   385.5
# modularity              0.682076
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014508485794067383 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      5
# max community size   1949
# avg. community size   321.25
# modularity              0.681946
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.011960983276367188 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      5
# max community size   1627
# avg. community size   398.793
# modularity              0.682525
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013731956481933594 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1781
# avg. community size   340.147
# modularity              0.683435
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03048396110534668 [s]
# solution properties:
# -------------------  ----------
# # communities          43
# min community size      3
# max community size   2604
# avg. community size   268.953
# modularity              0.67976
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02023172378540039 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      5
# max community size   1732
# avg. community size   312.568
# modularity              0.684214
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013401985168457031 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      4
# max community size   1980
# avg. community size   296.538
# modularity              0.681249
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.017882823944091797 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1796
# avg. community size   340.147
# modularity              0.684283
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.021215200424194336 [s]
# solution properties:
# -------------------  -----------
# # communities          49
# min community size      3
# max community size   2469
# avg. community size   236.02
# modularity              0.681703
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.020609378814697266 [s]
# solution properties:
# -------------------  ----------
# # communities          55
# min community size      2
# max community size   2538
# avg. community size   210.273
# modularity              0.68186
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.019134998321533203 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      4
# max community size   2054
# avg. community size   373.065
# modularity              0.683219
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.024257183074951172 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   2280
# avg. community size   289.125
# modularity              0.683155
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03744864463806152 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   1920
# avg. community size   282.073
# modularity              0.681504
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01619124412536621 [s]
# solution properties:
# -------------------  -----------
# # communities          26
# min community size      4
# max community size   1831
# avg. community size   444.808
# modularity              0.681082
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01548147201538086 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1789
# avg. community size   340.147
# modularity              0.681262
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014012575149536133 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1972
# avg. community size   361.406
# modularity              0.682013
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015245676040649414 [s]
# solution properties:
# -------------------  ----------
# # communities          31
# min community size      5
# max community size   1566
# avg. community size   373.065
# modularity              0.68438
# -------------------  ----------
# 22.3 ms ± 4.27 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## louvian method

# %%
# %timeit louvian_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.049889564514160156 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1896
# avg. community size   340.147
# modularity              0.683214
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01735973358154297 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1716
# avg. community size   340.147
# modularity              0.681024
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014238834381103516 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1750
# avg. community size   340.147
# modularity              0.682155
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.020569562911987305 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1782
# avg. community size   340.147
# modularity              0.685053
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0605618953704834 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      5
# max community size   1800
# avg. community size   398.793
# modularity              0.681676
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03294634819030762 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   1942
# avg. community size   304.342
# modularity              0.680147
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01986837387084961 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   1848
# avg. community size   330.429
# modularity              0.681473
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.053277015686035156 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      5
# max community size   1604
# avg. community size   312.568
# modularity              0.682711
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01662158966064453 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1732
# avg. community size   340.147
# modularity              0.681718
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01602029800415039 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1884
# avg. community size   340.147
# modularity              0.681966
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013339757919311523 [s]
# solution properties:
# -------------------  -----------
# # communities          46
# min community size      3
# max community size   2328
# avg. community size   251.413
# modularity              0.684703
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015684127807617188 [s]
# solution properties:
# -------------------  ---------
# # communities          32
# min community size      5
# max community size   1597
# avg. community size   361.406
# modularity              0.6831
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.10570025444030762 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      4
# max community size   1677
# avg. community size   350.455
# modularity              0.682606
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.06563735008239746 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   1680
# avg. community size   350.455
# modularity              0.680783
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.018190383911132812 [s]
# solution properties:
# -------------------  -----------
# # communities          38
# min community size      4
# max community size   1845
# avg. community size   304.342
# modularity              0.679746
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03392434120178223 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   1511
# avg. community size   350.455
# modularity              0.683016
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01684117317199707 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      4
# max community size   1768
# avg. community size   398.793
# modularity              0.682313
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015601873397827148 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      5
# max community size   1691
# avg. community size   350.455
# modularity              0.680502
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015345096588134766 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1693
# avg. community size   361.406
# modularity              0.681435
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01571512222290039 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   2209
# avg. community size   282.073
# modularity              0.684264
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013890743255615234 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      4
# max community size   1769
# avg. community size   385.5
# modularity              0.681721
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01557016372680664 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1571
# avg. community size   361.406
# modularity              0.684208
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014791727066040039 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      5
# max community size   1627
# avg. community size   330.429
# modularity              0.684224
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05066561698913574 [s]
# solution properties:
# -------------------  ----------
# # communities          38
# min community size      4
# max community size   2125
# avg. community size   304.342
# modularity              0.68519
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.018803834915161133 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      4
# max community size   2303
# avg. community size   321.25
# modularity              0.682557
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0406651496887207 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   1825
# avg. community size   282.073
# modularity              0.679994
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013192176818847656 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      4
# max community size   2127
# avg. community size   321.25
# modularity              0.681938
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01470494270324707 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      5
# max community size   1555
# avg. community size   385.5
# modularity              0.682493
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015137195587158203 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      4
# max community size   1814
# avg. community size   385.5
# modularity              0.681296
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01506948471069336 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      4
# max community size   1886
# avg. community size   350.455
# modularity              0.684081
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.017329931259155273 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1393
# avg. community size   361.406
# modularity              0.683343
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014112710952758789 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   1896
# avg. community size   330.429
# modularity              0.681005
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014110088348388672 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      2
# max community size   2694
# avg. community size   246.064
# modularity              0.679653
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0361180305480957 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      5
# max community size   1547
# avg. community size   373.065
# modularity              0.684038
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.016005992889404297 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      4
# max community size   1714
# avg. community size   312.568
# modularity              0.683216
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014626264572143555 [s]
# solution properties:
# -------------------  ----------
# # communities          41
# min community size      3
# max community size   2475
# avg. community size   282.073
# modularity              0.68212
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.017750263214111328 [s]
# solution properties:
# -------------------  ----------
# # communities          36
# min community size      5
# max community size   1683
# avg. community size   321.25
# modularity              0.68341
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.015535354614257812 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   2286
# avg. community size   340.147
# modularity              0.683212
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015285015106201172 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      4
# max community size   2267
# avg. community size   312.568
# modularity              0.680096
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014057397842407227 [s]
# solution properties:
# -------------------  -----------
# # communities          26
# min community size      5
# max community size   1791
# avg. community size   444.808
# modularity              0.681756
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013556480407714844 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      4
# max community size   2068
# avg. community size   296.538
# modularity              0.680303
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013123035430908203 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      5
# max community size   1772
# avg. community size   330.429
# modularity              0.681444
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015334367752075195 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   1795
# avg. community size   282.073
# modularity              0.679683
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.017661571502685547 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      5
# max community size   1579
# avg. community size   373.065
# modularity              0.684408
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.04124736785888672 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1758
# avg. community size   361.406
# modularity              0.681992
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01547861099243164 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      4
# max community size   2047
# avg. community size   296.538
# modularity              0.682994
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013754606246948242 [s]
# solution properties:
# -------------------  -----------
# # communities          33
# min community size      4
# max community size   1729
# avg. community size   350.455
# modularity              0.681669
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013773202896118164 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1717
# avg. community size   361.406
# modularity              0.682459
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014917135238647461 [s]
# solution properties:
# -------------------  ---------
# # communities          57
# min community size      2
# max community size   2537
# avg. community size   202.895
# modularity              0.6815
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.014469146728515625 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      4
# max community size   1792
# avg. community size   385.5
# modularity              0.681648
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014293909072875977 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size      5
# max community size   1510
# avg. community size   428.333
# modularity              0.683723
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013157367706298828 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      5
# max community size   1563
# avg. community size   340.147
# modularity              0.683412
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.015863418579101562 [s]
# solution properties:
# -------------------  ----------
# # communities          34
# min community size      4
# max community size   1687
# avg. community size   340.147
# modularity              0.68193
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013308286666870117 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      5
# max community size   1612
# avg. community size   373.065
# modularity              0.683393
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012817621231079102 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      5
# max community size   1708
# avg. community size   312.568
# modularity              0.683416
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01633167266845703 [s]
# solution properties:
# -------------------  -----------
# # communities          45
# min community size      3
# max community size   2665
# avg. community size   257
# modularity              0.680976
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.028170347213745117 [s]
# solution properties:
# -------------------  -----------
# # communities          47
# min community size      3
# max community size   2721
# avg. community size   246.064
# modularity              0.680266
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014405250549316406 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      5
# max community size   1619
# avg. community size   385.5
# modularity              0.679482
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01912689208984375 [s]
# solution properties:
# -------------------  -----------
# # communities          39
# min community size      5
# max community size   2039
# avg. community size   296.538
# modularity              0.683164
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01507711410522461 [s]
# solution properties:
# -------------------  -----------
# # communities          36
# min community size      5
# max community size   1701
# avg. community size   321.25
# modularity              0.682394
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.016056299209594727 [s]
# solution properties:
# -------------------  -----------
# # communities          37
# min community size      4
# max community size   2159
# avg. community size   312.568
# modularity              0.680412
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012742996215820312 [s]
# solution properties:
# -------------------  ---------
# # communities          24
# min community size      5
# max community size   1603
# avg. community size   481.875
# modularity              0.6819
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.01352834701538086 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   1686
# avg. community size   330.429
# modularity              0.682113
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013514280319213867 [s]
# solution properties:
# -------------------  -----------
# # communities          35
# min community size      4
# max community size   2172
# avg. community size   330.429
# modularity              0.681385
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014055490493774414 [s]
# solution properties:
# -------------------  ----------
# # communities          36
# min community size      5
# max community size   1830
# avg. community size   321.25
# modularity              0.68306
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013703584671020508 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1673
# avg. community size   340.147
# modularity              0.682753
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.013562917709350586 [s]
# solution properties:
# -------------------  ----------
# # communities          34
# min community size      5
# max community size   1713
# avg. community size   340.147
# modularity              0.68087
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013635873794555664 [s]
# solution properties:
# -------------------  ----------
# # communities          32
# min community size      3
# max community size   1914
# avg. community size   361.406
# modularity              0.68238
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.03238320350646973 [s]
# solution properties:
# -------------------  ----------
# # communities          29
# min community size      5
# max community size   1754
# avg. community size   398.793
# modularity              0.68192
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.014662504196166992 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      4
# max community size   1677
# avg. community size   398.793
# modularity              0.681854
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01602792739868164 [s]
# solution properties:
# -------------------  ----------
# # communities          31
# min community size      4
# max community size   1909
# avg. community size   373.065
# modularity              0.68082
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.015029668807983398 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      5
# max community size   1780
# avg. community size   373.065
# modularity              0.680155
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01574397087097168 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1518
# avg. community size   361.406
# modularity              0.684293
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.017344951629638672 [s]
# solution properties:
# -------------------  -----------
# # communities          32
# min community size      5
# max community size   1628
# avg. community size   361.406
# modularity              0.681509
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.02051854133605957 [s]
# solution properties:
# -------------------  -----------
# # communities          40
# min community size      4
# max community size   2090
# avg. community size   289.125
# modularity              0.680471
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.02067399024963379 [s]
# solution properties:
# -------------------  -----------
# # communities          41
# min community size      4
# max community size   2397
# avg. community size   282.073
# modularity              0.681549
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01610589027404785 [s]
# solution properties:
# -------------------  -----------
# # communities          34
# min community size      4
# max community size   1959
# avg. community size   340.147
# modularity              0.684952
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.03347301483154297 [s]
# solution properties:
# -------------------  -----------
# # communities          31
# min community size      4
# max community size   1770
# avg. community size   373.065
# modularity              0.681635
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.030127286911010742 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size      4
# max community size   1849
# avg. community size   398.793
# modularity              0.680864
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01621413230895996 [s]
# solution properties:
# -------------------  ----------
# # communities          31
# min community size      5
# max community size   1507
# avg. community size   373.065
# modularity              0.68235
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.013700246810913086 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size      5
# max community size   1913
# avg. community size   385.5
# modularity              0.678803
# -------------------  -----------
# 22.9 ms ± 5.46 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # centralities

# %% [markdown]
# ## betweenness centrality

# %%
# %timeit btwn_centrality = nk.centrality.Betweenness(G_nk).run()
# Out:
# 35.5 s ± 1.89 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit btwn_centrality = gt.betweenness(G_gt)
# Out:
# 14.9 s ± 89.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## closeness

# %%
# %timeit closeness_centrality = nk.centrality.Closeness(G_nk, False, nk.centrality.ClosenessVariant.Generalized)
# Out:
# 279 ns ± 3.41 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit closeness_centrality = gt.closeness(G_gt)
# Out:
# 16.6 s ± 1.27 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## degree

# %%
# %timeit degree_centrality = nk.centrality.DegreeCentrality(G_nk)
# Out:
# 202 ns ± 9.05 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## eigen vector

# %%
# %timeit eigen_centrality = nk.centrality.EigenvectorCentrality(G_nk)
# Out:
# 204 ns ± 5.61 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit eigen_centrality = gt.eigenvector(G_gt)
# Out:
# 6.23 ms ± 215 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## page rank

# %%
# %timeit page_rank_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 216 ns ± 9.73 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit page_rank_centrality = gt.pagerank(G_gt)
# Out:
# 16 ms ± 858 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## katz

# %%
# %timeit katz_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 211 ns ± 9.89 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit katz_centrality = gt.katz(G_gt)
# Out:
# 196 ms ± 3.35 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## HITS

# %%
# %timeit hits_centrality = gt.hits(G_gt)
# Out:
# 9.94 ms ± 179 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
