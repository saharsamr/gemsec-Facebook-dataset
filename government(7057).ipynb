# %%
import networkit as nk
import graph_tool.all as gt
import networkx as nx

import powerlaw
import matplotlib.pyplot as plt

from plots import Plots
from tools import values_frequency
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# ## load

# %%
snapReader = nk.graphio.SNAPGraphReader(False, False)
G_nk = snapReader.read("data/facebook_clean_data/government_edges.csv")

# %%
G_gt = gt.load_graph_from_csv("data/facebook_clean_data/government_edges.csv", csv_options={"delimiter": " "})

# %% [markdown]
# ## topology parameters

# %%
degrees = [G_nk.degree(v) for v in G_nk.iterNodes()]
degree_distr = sorted(nk.centrality.DegreeCentrality(G_nk).run().scores(), reverse=True)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_nk.numberOfNodes()))
print('number of edges: {}'.format(G_nk.numberOfEdges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 7057
# number of edges: 89455
# min degree: 1
# max degree: 697
# average degree: 25.348448349156865
# ----------------------------------------------------------------
# estimated gamma: 3.1012486620450312
# Calculating best minimal value for power law fit
# /home/sahar/Documents/NetworkAnalysis/venv/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /

# %%
degrees = G_gt.get_total_degrees(G_gt.get_vertices())
degree_distr, freq = values_frequency(degrees)
fitted_distr = powerlaw.Fit(degree_distr)

print('number of nodes: {}'.format(G_gt.num_vertices()))
print('number of edges: {}'.format(G_gt.num_edges()))
print('min degree: {}'.format(min(degrees)))
print('max degree: {}'.format(max(degrees)))
print('average degree: {}'.format(sum(degrees)/len(degrees)))
print('----------------------------------------------------------------')
print('estimated gamma: {}'.format(fitted_distr.alpha))
# Out:
# number of nodes: 7057
# number of edges: 89455
# min degree: 1
# max degree: 697
# average degree: 25.352132634263853
# ----------------------------------------------------------------
# estimated gamma: 4.129983496219724
# Calculating best minimal value for power law fit

# %% [markdown]
# ## graph density

# %%
# %time
graph_density = G_nk.numberOfEdges() / ((G_nk.numberOfNodes()*(G_nk.numberOfNodes()-1))/2)
print('the graph density equals: {}'.format(graph_density))
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# the graph density equals: 0.003592989318914945

# %% [markdown]
# ## clustering coefficient

# %%
# %time
clustering_coefficient = nk.globals.clustering(G_nk)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# the clustering coefficient of the graph equals: 0.4351168244593069

# %%
# %time
clustering_coefficient = gt.global_clustering(G_gt)
print('the clustering coefficient of the graph equals: {}'.format(clustering_coefficient[0]))
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.63 µs
# the clustering coefficient of the graph equals: 0.22376882168257833

# %% [markdown]
# ## assortativity

# %%
# %time
G_nx = nk.nxadapter.nk2nx(G_nk)
assortativity = nx.degree_assortativity_coefficient(G_nx)
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# assortativity coefficient is: 0.02936585901214625

# %%
# %time
assortativity = gt.assortativity(G_gt, "total")
print('assortativity coefficient is: {}'.format(assortativity))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs
# assortativity coefficient is: (0.003769110296278623, 0.0003659320692035869)

# %% [markdown]
# # community detection

# %% [markdown]
# ## label propagation

# %%
# %timeit label_prop_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.11234402656555176 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size     7
# max community size   962
# avg. community size  235.233
# modularity             0.727773
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010979413986206055 [s]
# solution properties:
# -------------------  -----------
# # communities          24
# min community size     89
# max community size   1340
# avg. community size   294.042
# modularity              0.726901
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.0103302001953125 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size     21
# max community size   1340
# avg. community size   252.036
# modularity              0.727111
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.008007049560546875 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   966
# avg. community size  252.036
# modularity             0.726943
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010277986526489258 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    59
# max community size   966
# avg. community size  261.37
# modularity             0.727251
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008437633514404297 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    21
# max community size   912
# avg. community size  271.423
# modularity             0.726758
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.05972909927368164 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   963
# avg. community size  243.345
# modularity             0.726986
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.019170284271240234 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size     59
# max community size   1118
# avg. community size   252.036
# modularity              0.728214
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.010534048080444336 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    29
# max community size   965
# avg. community size  243.345
# modularity             0.727206
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.03451037406921387 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   966
# avg. community size  261.37
# modularity             0.727388
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04953575134277344 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size     59
# max community size   1105
# avg. community size   252.036
# modularity              0.728284
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01260995864868164 [s]
# solution properties:
# -------------------  -----------
# # communities          30
# min community size     21
# max community size   1289
# avg. community size   235.233
# modularity              0.727403
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.010910749435424805 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   906
# avg. community size  243.345
# modularity             0.727847
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010870218276977539 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   964
# avg. community size  252.036
# modularity             0.725717
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01011204719543457 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   964
# avg. community size  243.345
# modularity             0.727418
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.007869958877563477 [s]
# solution properties:
# -------------------  ---------
# # communities         28
# min community size    21
# max community size   969
# avg. community size  252.036
# modularity             0.72579
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.026043415069580078 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    59
# max community size   966
# avg. community size  294.042
# modularity             0.727213
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.11288857460021973 [s]
# solution properties:
# -------------------  -----------
# # communities          24
# min community size     59
# max community size   1001
# avg. community size   294.042
# modularity              0.726877
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.05690884590148926 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    29
# max community size   966
# avg. community size  243.345
# modularity             0.726983
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04753708839416504 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   960
# avg. community size  252.036
# modularity             0.727833
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02731013298034668 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size     7
# max community size   913
# avg. community size  243.345
# modularity             0.726819
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.025784969329833984 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    76
# max community size   910
# avg. community size  271.423
# modularity             0.726515
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.014045000076293945 [s]
# solution properties:
# -------------------  ----------
# # communities         19
# min community size    89
# max community size   961
# avg. community size  371.421
# modularity             0.726335
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02433943748474121 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   952
# avg. community size  243.345
# modularity             0.726967
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010596752166748047 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    21
# max community size   963
# avg. community size  271.423
# modularity             0.727168
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009809494018554688 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    29
# max community size   994
# avg. community size  252.036
# modularity             0.726681
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008087873458862305 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   961
# avg. community size  252.036
# modularity             0.727324
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009082555770874023 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    30
# max community size   970
# avg. community size  271.423
# modularity             0.727044
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010182380676269531 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   971
# avg. community size  261.37
# modularity             0.727126
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009671449661254883 [s]
# solution properties:
# -------------------  ---------
# # communities         28
# min community size    21
# max community size   965
# avg. community size  252.036
# modularity             0.72565
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.03408384323120117 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    29
# max community size   961
# avg. community size  252.036
# modularity             0.727054
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0119781494140625 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    21
# max community size   948
# avg. community size  271.423
# modularity             0.727515
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.007890462875366211 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   983
# avg. community size  243.345
# modularity             0.727514
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009215354919433594 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    89
# max community size   985
# avg. community size  294.042
# modularity             0.724401
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009346723556518555 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   970
# avg. community size  252.036
# modularity             0.727222
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01961803436279297 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size     21
# max community size   1009
# avg. community size   243.345
# modularity              0.727526
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.01204538345336914 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   922
# avg. community size  243.345
# modularity             0.726933
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00946950912475586 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    76
# max community size   950
# avg. community size  271.423
# modularity             0.727078
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00953364372253418 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    21
# max community size   965
# avg. community size  271.423
# modularity             0.726955
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010141849517822266 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   964
# avg. community size  252.036
# modularity             0.725563
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008750677108764648 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   967
# avg. community size  261.37
# modularity             0.726889
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008536338806152344 [s]
# solution properties:
# -------------------  ----------
# # communities         20
# min community size    89
# max community size   968
# avg. community size  352.85
# modularity             0.724113
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.012471199035644531 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   958
# avg. community size  252.036
# modularity             0.727326
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008613824844360352 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    21
# max community size   972
# avg. community size  282.28
# modularity             0.725187
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00873875617980957 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   966
# avg. community size  261.37
# modularity             0.727102
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009730339050292969 [s]
# solution properties:
# -------------------  -----------
# # communities          24
# min community size     92
# max community size   1004
# avg. community size   294.042
# modularity              0.724883
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.021358728408813477 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    76
# max community size   907
# avg. community size  271.423
# modularity             0.727959
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01249551773071289 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    59
# max community size   960
# avg. community size  271.423
# modularity             0.726972
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01192927360534668 [s]
# solution properties:
# -------------------  ---------
# # communities         29
# min community size    21
# max community size   956
# avg. community size  243.345
# modularity             0.72776
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.008832693099975586 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    29
# max community size   966
# avg. community size  271.423
# modularity             0.727325
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00950169563293457 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   908
# avg. community size  261.37
# modularity             0.727865
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02690410614013672 [s]
# solution properties:
# -------------------  -----------
# # communities          26
# min community size     34
# max community size   1027
# avg. community size   271.423
# modularity              0.727276
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.00948023796081543 [s]
# solution properties:
# -------------------  ----------
# # communities         23
# min community size    90
# max community size   965
# avg. community size  306.826
# modularity             0.726893
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01814413070678711 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    91
# max community size   990
# avg. community size  294.042
# modularity             0.726493
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.015356063842773438 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   958
# avg. community size  261.37
# modularity             0.726979
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008321285247802734 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    29
# max community size   963
# avg. community size  261.37
# modularity             0.726965
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010294675827026367 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    63
# max community size   989
# avg. community size  261.37
# modularity             0.726439
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.007771968841552734 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    89
# max community size   961
# avg. community size  294.042
# modularity             0.726681
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.011124849319458008 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    59
# max community size   967
# avg. community size  271.423
# modularity             0.726669
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00923776626586914 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   988
# avg. community size  261.37
# modularity             0.726198
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008347272872924805 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    89
# max community size   967
# avg. community size  282.28
# modularity             0.726865
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.026336193084716797 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   919
# avg. community size  252.036
# modularity             0.727896
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.03986811637878418 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   969
# avg. community size  252.036
# modularity             0.726889
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02129364013671875 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   968
# avg. community size  243.345
# modularity             0.726847
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.020418405532836914 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   964
# avg. community size  252.036
# modularity             0.727383
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00935983657836914 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   966
# avg. community size  252.036
# modularity             0.726758
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00948786735534668 [s]
# solution properties:
# -------------------  ----------
# # communities         23
# min community size    76
# max community size   998
# avg. community size  306.826
# modularity             0.727359
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008640050888061523 [s]
# solution properties:
# -------------------  ---------
# # communities         28
# min community size    21
# max community size   961
# avg. community size  252.036
# modularity             0.72692
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.008279085159301758 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    29
# max community size   984
# avg. community size  261.37
# modularity             0.727219
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.011469125747680664 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size    29
# max community size   918
# avg. community size  235.233
# modularity             0.726966
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008871793746948242 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size     42
# max community size   1022
# avg. community size   261.37
# modularity              0.727306
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.007727146148681641 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   966
# avg. community size  252.036
# modularity             0.727326
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04433441162109375 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    21
# max community size   947
# avg. community size  271.423
# modularity             0.727294
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.024260759353637695 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   958
# avg. community size  252.036
# modularity             0.727306
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00915384292602539 [s]
# solution properties:
# -------------------  ---------
# # communities         25
# min community size    76
# max community size   951
# avg. community size  282.28
# modularity             0.72751
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.03248739242553711 [s]
# solution properties:
# -------------------  ---------
# # communities         25
# min community size    76
# max community size   913
# avg. community size  282.28
# modularity             0.72787
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.027795076370239258 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    59
# max community size   958
# avg. community size  271.423
# modularity             0.726948
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008292198181152344 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    63
# max community size   969
# avg. community size  252.036
# modularity             0.726699
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01918506622314453 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size     21
# max community size   1049
# avg. community size   243.345
# modularity              0.727904
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.008658885955810547 [s]
# solution properties:
# -------------------  ----------
# # communities          28
# min community size     21
# max community size   1271
# avg. community size   252.036
# modularity              0.72696
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009985923767089844 [s]
# solution properties:
# -------------------  ----------
# # communities         23
# min community size    59
# max community size   968
# avg. community size  306.826
# modularity             0.725982
# -------------------  ----------
# 19.9 ms ± 7.97 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## louvian method

# %%
# %timeit louvian_communities = nk.community.detectCommunities(G_nk, algo=nk.community.PLM(G_nk))
# Out:
# PLM(balanced,pc,turbo) detected communities in 0.08194351196289062 [s]
# solution properties:
# -------------------  ----------
# # communities          24
# min community size     59
# max community size   1128
# avg. community size   294.042
# modularity              0.72824
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.0612950325012207 [s]
# solution properties:
# -------------------  -----------
# # communities          25
# min community size     89
# max community size   1293
# avg. community size   282.28
# modularity              0.727226
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.046723365783691406 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   955
# avg. community size  261.37
# modularity             0.727558
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04173707962036133 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   965
# avg. community size  252.036
# modularity             0.727291
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04791665077209473 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    21
# max community size   961
# avg. community size  282.28
# modularity             0.727091
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.07593250274658203 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    59
# max community size   968
# avg. community size  271.423
# modularity             0.727055
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.18425393104553223 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size     63
# max community size   1306
# avg. community size   261.37
# modularity              0.727202
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.009377241134643555 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size    21
# max community size   968
# avg. community size  235.233
# modularity             0.726918
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009534597396850586 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size     7
# max community size   963
# avg. community size  235.233
# modularity             0.727271
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010097026824951172 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size     7
# max community size   966
# avg. community size  235.233
# modularity             0.727147
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00956106185913086 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    76
# max community size   954
# avg. community size  271.423
# modularity             0.727249
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009683847427368164 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   970
# avg. community size  261.37
# modularity             0.726345
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009711980819702148 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    76
# max community size   914
# avg. community size  282.28
# modularity             0.726487
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.018172025680541992 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    21
# max community size   993
# avg. community size  294.042
# modularity             0.726288
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009969711303710938 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   966
# avg. community size  243.345
# modularity             0.727065
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008831262588500977 [s]
# solution properties:
# -------------------  ----------
# # communities         31
# min community size    21
# max community size   978
# avg. community size  227.645
# modularity             0.727289
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00950765609741211 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    29
# max community size   962
# avg. community size  252.036
# modularity             0.727115
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008870363235473633 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   969
# avg. community size  243.345
# modularity             0.727233
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008798360824584961 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    89
# max community size   993
# avg. community size  294.042
# modularity             0.726256
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009705066680908203 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size    29
# max community size   970
# avg. community size  235.233
# modularity             0.726752
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.04067182540893555 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    76
# max community size   965
# avg. community size  271.423
# modularity             0.727259
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.1605675220489502 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    63
# max community size   909
# avg. community size  271.423
# modularity             0.727645
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.020152568817138672 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size    21
# max community size   965
# avg. community size  235.233
# modularity             0.727181
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010012388229370117 [s]
# solution properties:
# -------------------  -----------
# # communities          22
# min community size     89
# max community size   1002
# avg. community size   320.773
# modularity              0.726823
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.009309053421020508 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   960
# avg. community size  261.37
# modularity             0.727464
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008634328842163086 [s]
# solution properties:
# -------------------  --------
# # communities         28
# min community size    21
# max community size   915
# avg. community size  252.036
# modularity             0.7279
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.009752988815307617 [s]
# solution properties:
# -------------------  --------
# # communities         28
# min community size    34
# max community size   934
# avg. community size  252.036
# modularity             0.7276
# -------------------  --------
# PLM(balanced,pc,turbo) detected communities in 0.009289264678955078 [s]
# solution properties:
# -------------------  ---------
# # communities         29
# min community size    21
# max community size   966
# avg. community size  243.345
# modularity             0.72753
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.009044170379638672 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   984
# avg. community size  261.37
# modularity             0.727071
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01119232177734375 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size     62
# max community size   1304
# avg. community size   261.37
# modularity              0.727324
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.009809494018554688 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    63
# max community size   965
# avg. community size  261.37
# modularity             0.727176
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01033163070678711 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   970
# avg. community size  243.345
# modularity             0.727565
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009423017501831055 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    29
# max community size   916
# avg. community size  261.37
# modularity             0.727459
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010332584381103516 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   958
# avg. community size  252.036
# modularity             0.727596
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010834455490112305 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size     29
# max community size   1004
# avg. community size   243.345
# modularity              0.727117
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.009448766708374023 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   907
# avg. community size  243.345
# modularity             0.727979
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009674549102783203 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   958
# avg. community size  252.036
# modularity             0.726622
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.041815996170043945 [s]
# solution properties:
# -------------------  ----------
# # communities         23
# min community size    76
# max community size   911
# avg. community size  306.826
# modularity             0.726071
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.00973367691040039 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size    21
# max community size   907
# avg. community size  235.233
# modularity             0.727696
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01218104362487793 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   909
# avg. community size  243.345
# modularity             0.728009
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009880542755126953 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    59
# max community size   939
# avg. community size  261.37
# modularity             0.727556
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010314702987670898 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    63
# max community size   991
# avg. community size  261.37
# modularity             0.726998
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009421586990356445 [s]
# solution properties:
# -------------------  -----------
# # communities          28
# min community size     21
# max community size   1035
# avg. community size   252.036
# modularity              0.727503
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.009032249450683594 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   953
# avg. community size  243.345
# modularity             0.727111
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009404182434082031 [s]
# solution properties:
# -------------------  -----------
# # communities          26
# min community size     91
# max community size   1029
# avg. community size   271.423
# modularity              0.727262
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.009448766708374023 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    29
# max community size   910
# avg. community size  261.37
# modularity             0.728025
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010279655456542969 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   910
# avg. community size  243.345
# modularity             0.727978
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010040521621704102 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    59
# max community size   910
# avg. community size  271.423
# modularity             0.728039
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010179996490478516 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   955
# avg. community size  252.036
# modularity             0.727357
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010582923889160156 [s]
# solution properties:
# -------------------  -----------
# # communities          29
# min community size     21
# max community size   1045
# avg. community size   243.345
# modularity              0.727071
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.014865636825561523 [s]
# solution properties:
# -------------------  -----------
# # communities          27
# min community size     21
# max community size   1290
# avg. community size   261.37
# modularity              0.727305
# -------------------  -----------
# PLM(balanced,pc,turbo) detected communities in 0.012729883193969727 [s]
# solution properties:
# -------------------  ----------
# # communities         23
# min community size    89
# max community size   964
# avg. community size  306.826
# modularity             0.726754
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01401066780090332 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    89
# max community size   951
# avg. community size  282.28
# modularity             0.727489
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.03518986701965332 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size     7
# max community size   957
# avg. community size  252.036
# modularity             0.727549
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.025625944137573242 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   909
# avg. community size  252.036
# modularity             0.727329
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.014441490173339844 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    21
# max community size   968
# avg. community size  271.423
# modularity             0.727246
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.012869596481323242 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    76
# max community size   959
# avg. community size  282.28
# modularity             0.727693
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.008493185043334961 [s]
# solution properties:
# -------------------  ---------
# # communities         28
# min community size    65
# max community size   996
# avg. community size  252.036
# modularity             0.72758
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.009591817855834961 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    33
# max community size   962
# avg. community size  271.423
# modularity             0.727202
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009355545043945312 [s]
# solution properties:
# -------------------  ----------
# # communities         24
# min community size    21
# max community size   965
# avg. community size  294.042
# modularity             0.726827
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009371519088745117 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    29
# max community size   961
# avg. community size  243.345
# modularity             0.727542
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01114964485168457 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   961
# avg. community size  243.345
# modularity             0.727378
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009206056594848633 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   965
# avg. community size  243.345
# modularity             0.727373
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.01022791862487793 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   943
# avg. community size  252.036
# modularity             0.727178
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.011000394821166992 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    59
# max community size   928
# avg. community size  282.28
# modularity             0.726985
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010668039321899414 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   968
# avg. community size  261.37
# modularity             0.727542
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009116649627685547 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    63
# max community size   910
# avg. community size  252.036
# modularity             0.727526
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009122133255004883 [s]
# solution properties:
# -------------------  ---------
# # communities         30
# min community size     7
# max community size   965
# avg. community size  235.233
# modularity             0.72771
# -------------------  ---------
# PLM(balanced,pc,turbo) detected communities in 0.010384559631347656 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   912
# avg. community size  243.345
# modularity             0.727546
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.02600240707397461 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    63
# max community size   910
# avg. community size  271.423
# modularity             0.727893
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.011431694030761719 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   965
# avg. community size  261.37
# modularity             0.727453
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010640382766723633 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   959
# avg. community size  252.036
# modularity             0.727882
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010853290557861328 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   997
# avg. community size  243.345
# modularity             0.727486
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009191751480102539 [s]
# solution properties:
# -------------------  ----------
# # communities         29
# min community size    21
# max community size   965
# avg. community size  243.345
# modularity             0.727544
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.011553287506103516 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    21
# max community size   955
# avg. community size  261.37
# modularity             0.727515
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.011225700378417969 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    59
# max community size   951
# avg. community size  271.423
# modularity             0.727513
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010166645050048828 [s]
# solution properties:
# -------------------  ----------
# # communities         26
# min community size    63
# max community size   961
# avg. community size  271.423
# modularity             0.726441
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009610176086425781 [s]
# solution properties:
# -------------------  ----------
# # communities         25
# min community size    92
# max community size   978
# avg. community size  282.28
# modularity             0.726991
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009753704071044922 [s]
# solution properties:
# -------------------  ----------
# # communities         27
# min community size    59
# max community size   955
# avg. community size  261.37
# modularity             0.727458
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.009876251220703125 [s]
# solution properties:
# -------------------  ----------
# # communities         30
# min community size    21
# max community size   966
# avg. community size  235.233
# modularity             0.727348
# -------------------  ----------
# PLM(balanced,pc,turbo) detected communities in 0.010930299758911133 [s]
# solution properties:
# -------------------  ----------
# # communities         28
# min community size    21
# max community size   965
# avg. community size  252.036
# modularity             0.727053
# -------------------  ----------
# 16.5 ms ± 5.87 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # centralities

# %% [markdown]
# ## betweenness centrality

# %%
# %timeit btwn_centrality = nk.centrality.Betweenness(G_nk).run()
# Out:
# 18.3 s ± 2.2 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit btwn_centrality = gt.betweenness(G_gt)
# Out:
# 7.63 s ± 54.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## closeness

# %%
# %timeit closeness_centrality = nk.centrality.Closeness(G_nk, False, nk.centrality.ClosenessVariant.Generalized)
# Out:
# 252 ns ± 3.71 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit closeness_centrality = gt.closeness(G_gt)
# Out:
# 8.75 s ± 57.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## degree

# %%
# %timeit degree_centrality = nk.centrality.DegreeCentrality(G_nk)
# Out:
# 188 ns ± 6.39 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## eigen vector

# %%
# %timeit eigen_centrality = nk.centrality.EigenvectorCentrality(G_nk)
# Out:
# 185 ns ± 3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit eigen_centrality = gt.eigenvector(G_gt)
# Out:
# 9.66 ms ± 1.32 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## page rank

# %%
# %timeit page_rank_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 199 ns ± 7.69 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit page_rank_centrality = gt.pagerank(G_gt)
# Out:
# 18.1 ms ± 8.07 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## katz

# %%
# %timeit katz_centrality = nk.centrality.PageRank(G_nk, 1e-6)
# Out:
# 205 ns ± 7.58 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit katz_centrality = gt.katz(G_gt)
# Out:
# /usr/lib/python3/dist-packages/graph_tool/centrality/__init__.py:757: RuntimeWarning: invalid value encountered in true_divide
#   vprop.fa = vprop.fa / numpy.linalg.norm(vprop.fa)
# 8.81 s ± 139 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## HITS

# %%
# %timeit hits_centrality = gt.hits(G_gt)
# Out:
# 16.1 ms ± 751 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
